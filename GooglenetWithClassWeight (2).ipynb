# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11254586280687860246
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5726273536
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 284939167250895890
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# ]

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
import cv2
import glob
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import class_weight
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_df = pd.read_csv('./train.csv')
print("size of train_df:", len(train_df))

DATAGEN_TRAIN = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    data_format="channels_last",
    validation_split=0.10
) # Train / Validation

TRAIN_GENERATOR = DATAGEN_TRAIN.flow_from_dataframe(
    dataframe=train_df,
    x_col='img_path',
    y_col='artist',
    target_size=(244, 244),
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    subset="training"
)

VALID_GENERATOR = DATAGEN_TRAIN.flow_from_dataframe(
    dataframe=train_df,
    x_col='img_path',
    y_col='artist',
    target_size=(244, 244),
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    subset="validation"
)
# Out:
# size of train_df: 5911
# Found 5320 validated image filenames belonging to 50 classes.
# Found 591 validated image filenames belonging to 50 classes.

# %%
df = train_df.copy()
df['artist'].apply(lambda s: str(s).split('|'))
label_freq = df['artist'].apply(lambda s: str(s).split('|')).explode().value_counts().sort_values(ascending=False)
display(label_freq)
# Out:
# Vincent van Gogh             629
# Edgar Degas                  490
# Pablo Picasso                303
# Pierre-Auguste Renoir        233
# Albrecht Du rer              220
# Paul Gauguin                 220
# Francisco Goya               204
# Rembrandt                    181
# Titian                       173
# Marc Chagall                 173
# Alfred Sisley                164
# Paul Klee                    142
# Rene Magritte                137
# Amedeo Modigliani            132
# Andy Warhol                  132
# Henri Matisse                121
# Sandro Botticelli            120
# Mikhail Vrubel               118
# Hieronymus Bosch             115
# Leonardo da Vinci            101
# Salvador Dali                 99
# Peter Paul Rubens             97
# Kazimir Malevich              91
# Pieter Bruegel                85
# Frida Kahlo                   84
# Diego Velazquez               81
# Joan Miro                     76
# Andrei Rublev                 74
# Raphael                       73
# Giotto di Bondone             72
# Gustav Klimt                  69
# El Greco                      65
# Camille Pissarro              64
# Jan van Eyck                  64
# Edouard Manet                 62
# Henri de Toulouse-Lautrec     61
# Vasiliy Kandinskiy            60
# Claude Monet                  59
# Piet Mondrian                 59
# Henri Rousseau                52
# Diego Rivera                  50
# Edvard Munch                  44
# William Turner                44
# Gustave Courbet               42
# Michelangelo                  34
# Paul Cezanne                  33
# Caravaggio                    32
# Georges Seurat                30
# Eugene Delacroix              26
# Jackson Pollock               21
# Name: artist, dtype: int64

# %%
artist_df = df.copy()
label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(df['artist'].values)
class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(labels_encoded), y=labels_encoded)
class_weights_dic = {i: class_weights[i] for i in range(len(class_weights))}
class_weights_dic
# Out:
# {0: 0.5373636363636364,
#  1: 0.7208536585365853,
#  2: 0.8956060606060606,
#  3: 1.5975675675675676,
#  4: 0.8956060606060606,
#  5: 1.8471875,
#  6: 3.694375,
#  7: 2.003728813559322,
#  8: 2.3644,
#  9: 1.4595061728395062,
#  10: 0.24126530612244898,
#  11: 1.906774193548387,
#  12: 2.686818181818182,
#  13: 1.8187692307692307,
#  14: 4.546923076923077,
#  15: 0.5795098039215686,
#  16: 1.4073809523809524,
#  17: 3.9406666666666665,
#  18: 1.6419444444444444,
#  19: 1.7133333333333334,
#  20: 2.814761904761905,
#  21: 0.9770247933884297,
#  22: 2.2734615384615386,
#  23: 1.9380327868852458,
#  24: 1.028,
#  25: 5.62952380952381,
#  26: 1.8471875,
#  27: 1.5555263157894736,
#  28: 1.299120879120879,
#  29: 1.1704950495049504,
#  30: 0.6833526011560693,
#  31: 3.4770588235294118,
#  32: 1.001864406779661,
#  33: 0.39016501650165014,
#  34: 3.5824242424242425,
#  35: 0.5373636363636364,
#  36: 0.8325352112676057,
#  37: 1.218762886597938,
#  38: 0.5073819742489271,
#  39: 2.003728813559322,
#  40: 1.3908235294117648,
#  41: 1.6194520547945206,
#  42: 0.6531491712707183,
#  43: 0.862919708029197,
#  44: 1.1941414141414142,
#  45: 0.9851666666666666,
#  46: 0.6833526011560693,
#  47: 1.9703333333333333,
#  48: 0.18794912559618443,
#  49: 2.686818181818182}

# %%
# ResNet50 모델 로드
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(244, 244, 3), pooling=None, input_tensor=None)

# 새로운 Fully Connected Layer 추가
x = base_model.output
x = Flatten()(x)
x = Dropout(0.2)(x) # 드롭아웃 추가
predictions = Dense(50, activation='softmax')(x)

#전체 모델 구성
model = Model(inputs=base_model.input, outputs=predictions)

# 모델 컴파일
model.compile(optimizer=Adam(learning_rate=3e-4), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
CP = ModelCheckpoint(filepath='googlenet_model/' + 'GOOGLENET-Sigmoid-{epoch:03d}-{accuracy:.4f}-{val_loss:.4f}.hdf5',
                     monitor='val_loss', verbose=1, save_best_only=True, mode='min'
)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1, min_lr=0.00005)
CALLBACK = [CP, LR]

# %%
# 모델 학습
history = model.fit(
    TRAIN_GENERATOR,
    epochs=50,
    shuffle=True,
    callbacks=CALLBACK,
    validation_data=VALID_GENERATOR,
    class_weight=class_weights_dic
)
# Out:
# WARNING:tensorflow:From C:\Users\User\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\ops\array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/50
# 167/167 [==============================] - 68s 364ms/step - loss: 4.1582 - accuracy: 0.0568 - val_loss: 5.0578 - val_accuracy: 0.0728
#
# Epoch 00001: val_loss improved from inf to 5.05782, saving model to googlenet_model\GOOGLENET-Sigmoid-001-0.0568-5.0578.hdf5
# Epoch 2/50
# 167/167 [==============================] - 61s 367ms/step - loss: 3.0585 - accuracy: 0.2211 - val_loss: 4.1566 - val_accuracy: 0.1489
#
# Epoch 00002: val_loss improved from 5.05782 to 4.15660, saving model to googlenet_model\GOOGLENET-Sigmoid-002-0.2211-4.1566.hdf5
# Epoch 3/50
# 167/167 [==============================] - 61s 364ms/step - loss: 2.3355 - accuracy: 0.3429 - val_loss: 14.6080 - val_accuracy: 0.1794
#
# Epoch 00003: val_loss did not improve from 4.15660
# Epoch 4/50
# 167/167 [==============================] - 63s 376ms/step - loss: 1.8346 - accuracy: 0.4372 - val_loss: 2.7335 - val_accuracy: 0.3266
#
# Epoch 00004: val_loss improved from 4.15660 to 2.73350, saving model to googlenet_model\GOOGLENET-Sigmoid-004-0.4372-2.7335.hdf5
# Epoch 5/50
# 167/167 [==============================] - 68s 405ms/step - loss: 1.8695 - accuracy: 0.4538 - val_loss: 72.9138 - val_accuracy: 0.1506
#
# Epoch 00005: val_loss did not improve from 2.73350
# Epoch 6/50
# 167/167 [==============================] - 67s 398ms/step - loss: 1.7474 - accuracy: 0.4577 - val_loss: 2.9482 - val_accuracy: 0.3756
#
# Epoch 00006: val_loss did not improve from 2.73350
# Epoch 7/50
# 167/167 [==============================] - 70s 417ms/step - loss: 1.3318 - accuracy: 0.5487 - val_loss: 2.0133 - val_accuracy: 0.4670
#
# Epoch 00007: val_loss improved from 2.73350 to 2.01333, saving model to googlenet_model\GOOGLENET-Sigmoid-007-0.5487-2.0133.hdf5
# Epoch 8/50
# 167/167 [==============================] - 70s 420ms/step - loss: 1.0861 - accuracy: 0.6115 - val_loss: 4.7785 - val_accuracy: 0.4281
#
# Epoch 00008: val_loss did not improve from 2.01333
# Epoch 9/50
# 167/167 [==============================] - 72s 432ms/step - loss: 0.9446 - accuracy: 0.6479 - val_loss: 2.2564 - val_accuracy: 0.4670
#
# Epoch 00009: val_loss did not improve from 2.01333
# Epoch 10/50
# 167/167 [==============================] - 66s 392ms/step - loss: 0.9038 - accuracy: 0.6635 - val_loss: 3.4711 - val_accuracy: 0.4078
#
# Epoch 00010: val_loss did not improve from 2.01333
# Epoch 11/50
# 167/167 [==============================] - 63s 378ms/step - loss: 0.8829 - accuracy: 0.6720 - val_loss: 2.2280 - val_accuracy: 0.4805
#
# Epoch 00011: val_loss did not improve from 2.01333
# Epoch 12/50
# 167/167 [==============================] - 63s 375ms/step - loss: 0.7228 - accuracy: 0.7111 - val_loss: 2.1721 - val_accuracy: 0.5381
#
# Epoch 00012: val_loss did not improve from 2.01333
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# Epoch 13/50
# 167/167 [==============================] - 64s 381ms/step - loss: 0.4644 - accuracy: 0.7953 - val_loss: 1.6145 - val_accuracy: 0.6058
#
# Epoch 00013: val_loss improved from 2.01333 to 1.61451, saving model to googlenet_model\GOOGLENET-Sigmoid-013-0.7953-1.6145.hdf5
# Epoch 14/50
# 167/167 [==============================] - 66s 394ms/step - loss: 0.3580 - accuracy: 0.8293 - val_loss: 1.7318 - val_accuracy: 0.5973
#
# Epoch 00014: val_loss did not improve from 1.61451
# Epoch 15/50
# 167/167 [==============================] - 61s 366ms/step - loss: 0.3266 - accuracy: 0.8363 - val_loss: 1.6440 - val_accuracy: 0.6328
#
# Epoch 00015: val_loss did not improve from 1.61451
# Epoch 16/50
# 167/167 [==============================] - 65s 388ms/step - loss: 0.2961 - accuracy: 0.8513 - val_loss: 1.8878 - val_accuracy: 0.6159
#
# Epoch 00016: val_loss did not improve from 1.61451
# Epoch 17/50
# 167/167 [==============================] - 63s 378ms/step - loss: 0.2527 - accuracy: 0.8669 - val_loss: 1.6348 - val_accuracy: 0.6565
#
# Epoch 00017: val_loss did not improve from 1.61451
# Epoch 18/50
# 167/167 [==============================] - 63s 376ms/step - loss: 0.2679 - accuracy: 0.8660 - val_loss: 1.8790 - val_accuracy: 0.6024
#
# Epoch 00018: val_loss did not improve from 1.61451
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
# Epoch 19/50
# 167/167 [==============================] - 63s 376ms/step - loss: 0.1901 - accuracy: 0.8992 - val_loss: 1.4601 - val_accuracy: 0.6904
#
# Epoch 00019: val_loss improved from 1.61451 to 1.46005, saving model to googlenet_model\GOOGLENET-Sigmoid-019-0.8992-1.4601.hdf5
# Epoch 20/50
# 167/167 [==============================] - 63s 376ms/step - loss: 0.1566 - accuracy: 0.9147 - val_loss: 1.6517 - val_accuracy: 0.6717
#
# Epoch 00020: val_loss did not improve from 1.46005
# Epoch 21/50
# 167/167 [==============================] - 63s 376ms/step - loss: 0.1308 - accuracy: 0.9207 - val_loss: 1.5452 - val_accuracy: 0.6988
#
# Epoch 00021: val_loss did not improve from 1.46005
# Epoch 22/50
# 167/167 [==============================] - 63s 375ms/step - loss: 0.1246 - accuracy: 0.9293 - val_loss: 1.7925 - val_accuracy: 0.6734
#
# Epoch 00022: val_loss did not improve from 1.46005
# Epoch 23/50
# 167/167 [==============================] - 71s 427ms/step - loss: 0.1117 - accuracy: 0.9314 - val_loss: 1.5281 - val_accuracy: 0.7208
#
# Epoch 00023: val_loss did not improve from 1.46005
# Epoch 24/50
# 167/167 [==============================] - 74s 440ms/step - loss: 0.1009 - accuracy: 0.9412 - val_loss: 1.5647 - val_accuracy: 0.7107
#
# Epoch 00024: val_loss did not improve from 1.46005
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 5e-05.
# Epoch 25/50
# 167/167 [==============================] - 68s 407ms/step - loss: 0.1042 - accuracy: 0.9410 - val_loss: 1.5396 - val_accuracy: 0.7208
#
# Epoch 00025: val_loss did not improve from 1.46005
# Epoch 26/50
# 167/167 [==============================] - 65s 390ms/step - loss: 0.0900 - accuracy: 0.9481 - val_loss: 1.5274 - val_accuracy: 0.7225
#
# Epoch 00026: val_loss did not improve from 1.46005
# Epoch 27/50
# 167/167 [==============================] - 68s 407ms/step - loss: 0.0633 - accuracy: 0.9570 - val_loss: 1.5146 - val_accuracy: 0.7191
#
# Epoch 00027: val_loss did not improve from 1.46005
# Epoch 28/50
# 167/167 [==============================] - 67s 401ms/step - loss: 0.0829 - accuracy: 0.9532 - val_loss: 1.7634 - val_accuracy: 0.6920
#
# Epoch 00028: val_loss did not improve from 1.46005
# Epoch 29/50
# 167/167 [==============================] - 67s 402ms/step - loss: 0.0687 - accuracy: 0.9543 - val_loss: 1.6073 - val_accuracy: 0.7056
#
# Epoch 00029: val_loss did not improve from 1.46005
# Epoch 30/50
# 167/167 [==============================] - 68s 406ms/step - loss: 0.0635 - accuracy: 0.9620 - val_loss: 1.6598 - val_accuracy: 0.7124
#
# Epoch 00030: val_loss did not improve from 1.46005
# Epoch 31/50
# 167/167 [==============================] - 71s 423ms/step - loss: 0.0754 - accuracy: 0.9570 - val_loss: 1.5477 - val_accuracy: 0.7276
#
# Epoch 00031: val_loss did not improve from 1.46005
# Epoch 32/50
# 167/167 [==============================] - 70s 416ms/step - loss: 0.0769 - accuracy: 0.9551 - val_loss: 1.5199 - val_accuracy: 0.7140
#
# Epoch 00032: val_loss did not improve from 1.46005
# Epoch 33/50
# 167/167 [==============================] - 70s 419ms/step - loss: 0.0695 - accuracy: 0.9590 - val_loss: 1.8189 - val_accuracy: 0.7022
#
# Epoch 00033: val_loss did not improve from 1.46005
# Epoch 34/50
# 167/167 [==============================] - 76s 452ms/step - loss: 0.0714 - accuracy: 0.9594 - val_loss: 1.5283 - val_accuracy: 0.7157
#
# Epoch 00034: val_loss did not improve from 1.46005
# Epoch 35/50
# 167/167 [==============================] - 77s 460ms/step - loss: 0.0674 - accuracy: 0.9598 - val_loss: 1.6726 - val_accuracy: 0.6904
#
# Epoch 00035: val_loss did not improve from 1.46005
# Epoch 36/50
# 167/167 [==============================] - 73s 433ms/step - loss: 0.0635 - accuracy: 0.9628 - val_loss: 1.6905 - val_accuracy: 0.7073
#
# Epoch 00036: val_loss did not improve from 1.46005
# Epoch 37/50
# 167/167 [==============================] - 75s 450ms/step - loss: 0.0723 - accuracy: 0.9607 - val_loss: 1.5840 - val_accuracy: 0.7191
#
# Epoch 00037: val_loss did not improve from 1.46005
# Epoch 38/50
# 167/167 [==============================] - 76s 455ms/step - loss: 0.0712 - accuracy: 0.9583 - val_loss: 1.6572 - val_accuracy: 0.7056
#
# Epoch 00038: val_loss did not improve from 1.46005
# Epoch 39/50
# 167/167 [==============================] - 76s 454ms/step - loss: 0.0535 - accuracy: 0.9664 - val_loss: 1.7124 - val_accuracy: 0.7157
#
# Epoch 00039: val_loss did not improve from 1.46005
# Epoch 40/50
# 167/167 [==============================] - 74s 440ms/step - loss: 0.0523 - accuracy: 0.9699 - val_loss: 1.5949 - val_accuracy: 0.7276
#
# Epoch 00040: val_loss did not improve from 1.46005
# Epoch 41/50
# 167/167 [==============================] - 77s 459ms/step - loss: 0.0500 - accuracy: 0.9724 - val_loss: 1.8709 - val_accuracy: 0.6971
#
# Epoch 00041: val_loss did not improve from 1.46005
# Epoch 42/50
# 167/167 [==============================] - 77s 462ms/step - loss: 0.0610 - accuracy: 0.9648 - val_loss: 1.8387 - val_accuracy: 0.7022
#
# Epoch 00042: val_loss did not improve from 1.46005
# Epoch 43/50
# 167/167 [==============================] - 73s 436ms/step - loss: 0.0710 - accuracy: 0.9592 - val_loss: 1.8719 - val_accuracy: 0.7039
#
# Epoch 00043: val_loss did not improve from 1.46005
# Epoch 44/50
# 167/167 [==============================] - 78s 467ms/step - loss: 0.0536 - accuracy: 0.9703 - val_loss: 1.7241 - val_accuracy: 0.7428
#
# Epoch 00044: val_loss did not improve from 1.46005
# Epoch 45/50
# 167/167 [==============================] - 77s 460ms/step - loss: 0.0532 - accuracy: 0.9692 - val_loss: 1.7931 - val_accuracy: 0.7208
#
# Epoch 00045: val_loss did not improve from 1.46005
# Epoch 46/50
# 167/167 [==============================] - 76s 450ms/step - loss: 0.0599 - accuracy: 0.9618 - val_loss: 1.8797 - val_accuracy: 0.7107
#
# Epoch 00046: val_loss did not improve from 1.46005
# Epoch 47/50
# 167/167 [==============================] - 74s 444ms/step - loss: 0.0505 - accuracy: 0.9707 - val_loss: 1.7455 - val_accuracy: 0.6988
#
# Epoch 00047: val_loss did not improve from 1.46005
# Epoch 48/50
# 167/167 [==============================] - 78s 465ms/step - loss: 0.0533 - accuracy: 0.9652 - val_loss: 1.7504 - val_accuracy: 0.7157
#
# Epoch 00048: val_loss did not improve from 1.46005
# Epoch 49/50
# 167/167 [==============================] - 78s 467ms/step - loss: 0.0381 - accuracy: 0.9782 - val_loss: 1.7231 - val_accuracy: 0.7174
#
# Epoch 00049: val_loss did not improve from 1.46005
# Epoch 50/50
# 167/167 [==============================] - 73s 438ms/step - loss: 0.0356 - accuracy: 0.9758 - val_loss: 1.8327 - val_accuracy: 0.6920
#
# Epoch 00050: val_loss did not improve from 1.46005

# %%
# 손실 그래프
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Training Loss vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['loss', 'val_loss'])
plt.show()

# %%
# 정확도 그래프
plt.plot([x * 100 for x in history.history['accuracy']])
plt.plot([x * 100 for x in history.history['val_accuracy']])
plt.title('Training Accuracy vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend(['accuracy', 'val_accuracy'])
plt.show()

# %%
# 최신 체크포인트 파일 찾기
checkpoint_files = glob.glob('googlenet_model/*.hdf5')
latest_checkpoint = max(checkpoint_files, key=os.path.getctime)

# 모델에 최신 가중치 로드
model.load_weights(latest_checkpoint)

# Validation 데이터에 대한 정확도 확인
val_loss, val_accuracy = model.evaluate(VALID_GENERATOR)
print('Validation Loss:', round(val_loss, 6))
print('Validation Accuracy:', round(val_accuracy, 3))
# Out:
# 19/19 [==============================] - 7s 361ms/step - loss: 1.4768 - accuracy: 0.6887
# Validation Loss: 1.476751
# Validation Accuracy: 0.689

# %%
test_df = pd.read_csv('test.csv')

TEST_GENERATOR = DATAGEN_TRAIN.flow_from_dataframe(
    dataframe=test_df,
    x_col='img_path',
    y_col='id',
    target_size=(244, 244),
    class_mode='raw',
    batch_size=32,
    shuffle=False,
)

TEST_GENERATOR.reset()

# 최신 체크포인트 파일 찾기
checkpoint_files = glob.glob('googlenet_model/*.hdf5')
latest_checkpoint = max(checkpoint_files, key=os.path.getctime)

# 모델에 최신 가중치 로드
model.load_weights(latest_checkpoint)

test_prediction = model.predict(TEST_GENERATOR, verbose=1)
display(test_prediction)
# Out:
# Found 12670 validated image filenames.
# 396/396 [==============================] - 258s 651ms/step
# array([[4.2016062e-04, 1.9414101e-05, 2.8865237e-04, ..., 2.4568662e-06,
#         1.6901284e-02, 2.7563513e-07],
#        [3.0472425e-03, 2.3316413e-06, 1.2950212e-01, ..., 3.1625937e-08,
#         2.1216646e-01, 1.0253056e-04],
#        [5.1197123e-05, 1.6110356e-10, 5.1853322e-10, ..., 2.6975047e-09,
#         3.1801359e-05, 9.3455556e-11],
#        ...,
#        [4.5231151e-04, 2.0715753e-08, 2.6883224e-01, ..., 7.4767954e-08,
#         4.9135727e-03, 2.2368587e-08],
#        [1.2656617e-04, 8.9501100e-08, 7.2886742e-06, ..., 3.1961669e-08,
#         1.0068347e-04, 1.5068955e-06],
#        [8.1997263e-05, 6.5415759e-07, 3.3206565e-05, ..., 2.3471420e-09,
#         9.8146683e-01, 1.6489894e-07]], dtype=float32)

# %%
test_prediction = np.argmax(test_prediction, axis = 1)
test_prediction
# Out:
# array([33, 12,  6, ..., 33, 46, 48], dtype=int64)

# %%
test_prediction_df = pd.DataFrame(test_prediction, columns = ['artist'])
test_prediction_df
# Out:
#        artist
# 0          33
# 1          12
# 2           6
# 3           0
# 4          12
# ...       ...
# 12665      10
# 12666       2
# 12667      33
# 12668      46
# 12669      48
#
# [12670 rows x 1 columns]

# %%
artist_df = train_df.copy()
artist_le = label_encoder.fit_transform(artist_df['artist'].values)
artist_df['num'] = artist_le
artist_df = artist_df.drop('id', axis=1)
artist_df = artist_df.drop('img_path', axis=1)
test_prediction_dic = test_prediction_df.to_dict()
test_prediction_values = test_prediction_dic['artist'].values()
test_prediction_list = list(test_prediction_values)
artist_df.set_index('num', inplace=True)
artist_df = artist_df.sort_index()
artist_info_dic = artist_df['artist'].to_dict()

# %%
artist_name = []
for i in test_prediction_list:
    artist_name.append(artist_info_dic[i])
artist_name[:5]
# Out:
# ['Pablo Picasso',
#  'Edvard Munch',
#  'Caravaggio',
#  'Albrecht Du rer',
#  'Edvard Munch']

# %%
submission_df = pd.read_csv("./sample_submission.csv")
submission_df = submission_df.drop('artist', axis=1)
submission_df['artist'] = artist_name
submission_df.head()
# Out:
#            id           artist
# 0  TEST_00000    Pablo Picasso
# 1  TEST_00001     Edvard Munch
# 2  TEST_00002       Caravaggio
# 3  TEST_00003  Albrecht Du rer
# 4  TEST_00004     Edvard Munch

# %%
submission_df.to_csv("googlenet_submission.csv", index=False)
